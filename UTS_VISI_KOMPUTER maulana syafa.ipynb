# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from skimage.exposure import histogram
img = mpimg.imread('uls.jfif')
plt.imshow(img)

# %%
ret, img_binary = cv2.threshold(img, 50, 180, cv2.THRESH_BINARY)
plt.imshow(img_binary)
plt.show()

# %%
freq, bins = histogram(img)
plt.step(bins, freq*1.0/freq.sum())
plt.xlabel('Intensity value')
plt.ylabel('Fraction of pixels');

# %% [markdown]
# Maulana syafa aditya hidayat

# %% [markdown]
# NIM = 23421018 | yang dipakai 018 tetapi disuruh mengubah ke 180

# %% [markdown]
# Nilai Maksimum 180
